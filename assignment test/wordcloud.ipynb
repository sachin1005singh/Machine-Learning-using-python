# %%
! pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached https://files.pythonhosted.org/packages/23/4e/1254d26ce5d36facdcbb5820e7e434328aed68e99938c75c9d4e2fee5efb/wordcloud-1.5.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (5.3.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.15.4)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.5.0

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (5.3.0)

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_json('jsondata.json')
df.head()
# Out:
#            added                   country  end_year impact  \
# 0  1484884285000  United States of America         0
# 1  1484884284000  United States of America         0
# 2  1484884283000  United States of America         0
# 3  1484882800000                    Mexico         0
# 4  1484787354000                                   0
#
#                                              insight intensity likelihood  \
# 0                              Annual Energy Outlook         6          3
# 1                              Annual Energy Outlook         6          3
# 2                              Annual Energy Outlook         6          3
# 3  WRI Partnership Aims to Foster Supply Chain Tr...         6          2
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...         6          3
#
#           pestle                  published            region relevance  \
# 0     Industries  January, 09 2017 00:00:00  Northern America         2
# 1     Industries  January, 09 2017 00:00:00  Northern America         2
# 2     Industries  January, 09 2017 00:00:00  Northern America         2
# 3  Environmental  January, 18 2017 00:00:00   Central America         3
# 4       Economic  January, 18 2017 00:00:00             World         2
#
#         sector                 source  start_year  \
# 0       Energy                    EIA         NaN
# 1       Energy                    EIA         NaN
# 2       Energy                    EIA         NaN
# 3  Environment  sustainablebrands.com         NaN
# 4                              SBWire         NaN
#
#                                                title        topic  \
# 0  U.S. natural gas consumption is expected to in...          gas
# 1  Reference case U.S. crude oil production is pr...          oil
# 2  U.S. petroleum consumption is projected to rem...  consumption
# 3  Mars, Unilever, Cargill and MondelÄ“z are alre...          oil
# 4  Polymerization will remain top 3 end-users in ...       market
#
#                                                  url
# 0  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...
# 1  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...
# 2  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...
# 3  http://www.sustainablebrands.com/news_and_view...
# 4  http://www.sbwire.com/press-releases/n-hexane-...

# %%
print("There are {} observations and {} features in this dataset. \n".format(df.shape[0],df.shape[1]))

print("There are {} types of Topics  in this dataset such as {}... \n".format(len(df.topic.unique()),
                                                                           ", ".join(df.topic.unique()[0:5])))
print("There are {} countries producing wine in this dataset such as {}... \n".format(len(df.country.unique()),
                                                                                      ','.join(df.country.unique()[0:5])))
# Out:
# There are 1000 observations and 17 features in this dataset.
#
# There are 98 types of Topics  in this dataset such as gas, oil, consumption, market, gdp...
#
# There are 57 countries producing wine in this dataset such as United States of America,Mexico,,Nigeria,Lebanon...

# %%
#df['region'].value_counts()

# %%
df[["country", "topic","likelihood"]].head()
# Out:
#                     country        topic likelihood
# 0  United States of America          gas          3
# 1  United States of America          oil          3
# 2  United States of America  consumption          3
# 3                    Mexico          oil          2
# 4                                 market          3
