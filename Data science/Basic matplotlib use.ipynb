# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(5,100,100)

# %%
y = np.linspace(10,100,100)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot([1,2,3,46],[34,76,78,89])

# %%
## scatter used to create dot graph

# %%
plt.scatter([0,9,7,3],[2,1,8])
plt.show()
