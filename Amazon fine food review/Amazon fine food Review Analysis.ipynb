# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
review_data= pd.read_csv('Reviews.csv')
review_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
review_data.shape
# Out:
# (568454, 10)

# %%
import sqlite3
conn = sqlite3.connect('database.sqlite') # using SQLite Table to read data

# %% [markdown]
# Not considering reviews with score= 3, so filtering data for score= 3

# %%
filtered_data= pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3 """, conn)

# %% [markdown]
# Encode Reviews with Score> 3 with positive and Score< 3 negative rating.

# %%
def partition(x):
    if x<3:
        return 0
    return 1

actualScore= filtered_data['Score']
positiveNegative= actualScore.map(partition)
filtered_data['Score']= positiveNegative

# %%
filtered_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      1  1303862400
# 1                     0                       0      0  1346976000
# 2                     1                       1      1  1219017600
# 3                     3                       3      0  1307923200
# 4                     0                       0      1  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
filtered_data['Score'].value_counts()
# Out:
# 1    443777
# 0     82037
# Name: Score, dtype: int64

# %% [markdown]
# i.e, data is imbalanced

# %% [markdown]
# **Data Cleaning:** Remove duplicate data rows
#
# It is necessary to remove duplicates in order to get unbiased results for the analysis of the data.

# %%
filtered_data['UserId'].value_counts().head(10)
# Out:
# A3OXHLG6DIBRW8    425
# A1YUL9PCJR3JTY    391
# AY12DBB0U420B     365
# A281NPSIMI1C2R    346
# A1Z54EM24Y40LL    230
# A3TVZM3ZIXG8YW    199
# A1TMAVN4CEM8U8    196
# A3PJZ8TU8FDQ1K    173
# A29JUMRL1US6YP    171
# A2MUGFV2TDQ47K    161
# Name: UserId, dtype: int64

# %%
filtered_data[filtered_data['UserId']== 'A3OXHLG6DIBRW8'].head()
# Out:
#         Id   ProductId          UserId       ProfileName  \
# 338    370  B002O3VHXU  A3OXHLG6DIBRW8  C. F. Hill "CFH"
# 753    814  B004ET7MG8  A3OXHLG6DIBRW8  C. F. Hill "CFH"
# 3034  3307  B005K4Q1VI  A3OXHLG6DIBRW8  C. F. Hill "CFH"
# 3139  3417  B005K4Q1VI  A3OXHLG6DIBRW8  C. F. Hill "CFH"
# 3613  3927  B000VSDFRG  A3OXHLG6DIBRW8  C. F. Hill "CFH"
#
#       HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 338                      1                       1      1  1282176000
# 753                      3                       4      0  1272240000
# 3034                    24                      25      1  1321401600
# 3139                     5                       5      1  1321401600
# 3613                     2                       2      1  1237161600
#
#                                                 Summary  \
# 338             Very Smooth Coffee - Highly Recommended
# 753                   Odd Fake Flavor - Not Recommended
# ...

# %%
sorted_data= filtered_data.sort_values('ProductId', axis= 0, na_position= 'last')  #na_position= 'last' means data with NaN will come at last

# %%
sorted_data.head()
# Out:
#             Id   ProductId          UserId                  ProfileName  \
# 138706  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 138688  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 138689  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 138690  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 138691  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 138706                     0                       0      1   939340800
# 138688                     1                       1      1  1194739200
# 138689                     1                       1      1  1191456000
# 138690                     1                       1      1  1076025600
# 138691                     3                       4      1  1018396800
#
#                                            Summary  \
# ...

# %%
sorted_data.tail()
# Out:
#             Id   ProductId          UserId        ProfileName  \
# 176791  191721  B009UOFTUI   AJVB004EB0MVK  D. Christofferson
# 1362      1478  B009UOFU20   AJVB004EB0MVK  D. Christofferson
# 303285  328482  B009UUS05I   ARL20DSHGVM1Y              Jamie
# 5259      5703  B009WSNWC4   AMP7K1O84DH1T               ESTY
# 302474  327601  B009WVB40S  A3ME78KVX31T21               K'la
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 176791                     0                       0      0  1345852800
# 1362                       0                       0      0  1345852800
# 303285                     0                       0      1  1331856000
# 5259                       0                       0      1  1351209600
# 302474                     0                       0      1  1351123200
#
#                                                   Summary  \
# 176791  weak coffee not good for a premium product and...
# ...

# %% [markdown]
# Duplicate entries:

# %%
final= sorted_data.drop_duplicates(subset= {'UserId', 'ProfileName', 'Time', 'Text'}, keep= 'first')
final.shape
# Out:
# (364173, 10)

# %% [markdown]
# Fraction of original data left unique:

# %%
(final['Id'].size*1.0)/(filtered_data['Id'].size*1.0)*100
# Out:
# 69.25890143662969

# %% [markdown]
# HelpfullnessNumerator must be <= HelpfullnessDenominator if not then remove such rows

# %%
final[final.HelpfulnessNumerator > final.HelpfulnessDenominator]
# Out:
#           Id   ProductId          UserId              ProfileName  \
# 59301  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
# 41159  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 59301                     3                       1      1  1224892800
# 41159                     3                       2      1  1212883200
#
#                                             Summary  \
# 59301             Bought This for My Son at College
# 41159  Pure cocoa taste with crunchy almonds inside
#
#                                                     Text
# 59301  My son loves spaghetti so I didn't hesitate or...
# 41159  It was almost a 'love at first bite' - the per...

# %%
final= final[final.HelpfulnessNumerator <= final.HelpfulnessDenominator]
final.shape

# %%
final['score'].value_counts()

# %% [markdown]
# **Text Processing:** Stemming, stop-word removal and lemmatization
# - In the preprocessing phase we do the following in the order below:
#     - begin by removing html tags
#     - remove any punctuations or limited set of special characters like , or . or # etc.
#     - check if thw word is made up of english letters and is not alpha-numeric.
#     - check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters)
#     - convert all the word to lowercase
#     - remove stop-words
#     - finally snowball stemming the word( it was observed better than Poter Stemming)

# %% [markdown]
# Find sentences containing HTML tags:

# %%
import re
i= 0
for sent in final['Text'].values:
    if (len(re.findall('<.*?>', sent))):
        print(i)
        print(sent)
        break
    i+= 1
# Out:
# 6
# I set aside at least an hour each day to read to my son (3 y/o). At this point, I consider myself a connoisseur of children's books and this is one of the best. Santa Clause put this under the tree. Since then, we've read it perpetually and he loves it.<br /><br />First, this book taught him the months of the year.<br /><br />Second, it's a pleasure to read. Well suited to 1.5 y/o old to 4+.<br /><br />Very few children's books are worth owning. Most should be borrowed from the library. This book, however, deserves a permanent spot on your shelf. Sendak's best.

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
stop= set(stopwords.words('english'))     # set stop-word
sno= nltk.stem.SnowballStemmer('english') # initialising the snowball stemmer

# %%
def cleanhtml(sentence): # function to clean the word of any html-tags
    cleantext= re.sub(r'<.*?>',' ', sentence)
    return cleantext

def cleanpunc(sentence): # function to clean punctuation or special characters
    cleaned= re.sub(r'[?|!|\'|"|#]', r'', sentence)
    cleaned= re.sub(r'[.|,|)|(|\|/]', r' ', sentence)
    return cleaned
# print(f'Stop words are: {stop}')
# Out:
# Stop words are: {'some', 'until', 'ain', 'itself', 'is', 'at', 'it', "mustn't", 'been', 'or', 'won', 'any', 'can', 'while', 'am', 'against', 'having', 'there', 'isn', 'nor', "mightn't", 'more', 'when', 'an', 've', 'don', 'we', 'the', 'very', 'they', 'have', 'hadn', 'how', 'up', 'weren', 'about', 'those', 'from', 'why', 'its', 'over', 'all', 'further', 'theirs', 'whom', 'under', "wasn't", "won't", 'will', 'once', 'now', 'before', "weren't", "couldn't", 'a', 'was', 'ma', 'so', 'but', "you'll", 'll', 'as', "hasn't", "don't", 'no', 'same', 'few', 'down', 'needn', 'his', 'shouldn', 'hers', 'other', 'm', 'below', "doesn't", 'doing', 'just', 'you', 'yourself', 't', 'has', 'during', 'own', "you're", 'which', 'through', 'should', 'didn', 'this', 'are', 'then', 'do', 'for', 'these', "isn't", "it's", 'our', 'herself', 'not', 'on', 'couldn', 'with', 's', 'out', 'than', 'into', 'shan', 'who', 'that', 'wouldn', 'in', 'here', 'off', 'were', 'both', 're', 'myself', 'i', 'she', "that'll", 'him', 'of'
# ...

# %%
i= 0
str1= ''
final_string= []
all_pos_words= []
all_neg_words= []
s= ''

for sent in final['Text'].values:
    filtered_sentences=[]
    sent= cleanhtml(sent) # remove html tags
    
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if ((cleaned_words.isalpha()) & (len(cleaned_words)> 2)):
                if (cleaned_words.lower() not in stop):
                    s= sno.stem(cleaned_words.lower())
                    filtered_sentences.append(s)
                    if (final['Score'].values)[i]== 1:
                        all_pos_words.append(s)
                    if (final['Score'].values)[i]== 0:
                        all_neg_words.append(s)
                else:
                    continue
            else:
                continue
            
    str1= " ".join(filtered_sentences)
    
    final_string.append(str1)
    i+= 1

# %%
final['CleanedText']= final_string  # adding column of CleanedText
final.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             Id   ProductId          UserId                  ProfileName  \
# 138706  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 138688  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 138689  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 138690  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 138691  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 138706                     0                       0      1   939340800
# ...

# %%
final[['Text', 'CleanedText']].head()
# Out:
#                                                      Text  \
# 138706  this witty little book makes my son laugh at l...
# 138688  I grew up reading these Sendak books, and watc...
# 138689  This is a fun way for children to learn their ...
# 138690  This is a great little book to read aloud- it ...
# 138691  This is a book of poetry about the months of t...
#
#                                               CleanedText
# 138706  witti littl book make son laugh loud recit car...
# 138688  grew read sendak book watch realli rosi movi i...
# 138689  fun way children learn month learn poem throug...
# 138690  great littl book read nice rhythm well good re...
# 138691  book poetri month year goe month cute littl po...

# %%
final.to_csv('Cleaned_text.csv', index= False) # saving cleaned data

# %%
final= pd.read_csv('Cleaned_text.csv')
final.head()
# Out:
#        Id   ProductId          UserId                  ProfileName  \
# 0  150524  0006641040   ACITT7DI6IDDL              shari zychinski
# 1  150506  0006641040  A2IW4PEEKO2R0U                        Tracy
# 2  150507  0006641040  A1S4A3IQ2MU7V4        sally sue "sally sue"
# 3  150508  0006641040     AZGXZ2UUK6X  Catherine Hallberg "(Kate)"
# 4  150509  0006641040  A3CMRKGE0P909G                       Teresa
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     0                       0      1   939340800
# 1                     1                       1      1  1194739200
# 2                     1                       1      1  1191456000
# 3                     1                       1      1  1076025600
# 4                     3                       4      1  1018396800
#
#                                       Summary  \
# 0                   EVERY book is educational
# 1  Love the book, miss the hard cover version
# ...
